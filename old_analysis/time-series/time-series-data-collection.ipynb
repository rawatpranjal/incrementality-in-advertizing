# %%
import os
import pandas as pd
from tabulate import tabulate
from dotenv import load_dotenv
import snowflake.connector
import sys
from datetime import datetime, timedelta
from tqdm import tqdm

load_dotenv()

# Create data folder if it doesn't exist
os.makedirs('data', exist_ok=True)

# --- Snowflake connection ---
conn = snowflake.connector.connect(
    user=os.getenv('SNOWFLAKE_USER'),
    password=os.getenv('SNOWFLAKE_PASSWORD'),
    account=os.getenv('SNOWFLAKE_ACCOUNT'),
    warehouse=os.getenv('SNOWFLAKE_WAREHOUSE', 'COMPUTE_WH'),
    database='INCREMENTALITY',
    schema='INCREMENTALITY_RESEARCH'
)
cursor = conn.cursor()

def run_query(query):
    try:
        cursor.execute(query)
        if cursor.description:
            results = cursor.fetchall()
            columns = [desc[0] for desc in cursor.description]
            return pd.DataFrame(results, columns=columns)
        return pd.DataFrame()
    except snowflake.connector.ProgrammingError as e:
        print(f"\nERROR executing query:\n{query}\nDetails: {e}")
        raise

def show_table(df, title=""):
    if title:
        print(f"\n{title}")
        print("="*len(title))
    print(tabulate(df, headers='keys', tablefmt='grid', showindex=False))

print("✅ Connected to Snowflake")
# Out:
# ✅ Connected to Snowflake

# %% [markdown]
# # purchases

# %%
  # --- CONFIGURATION ---
  ANALYSIS_START_DATE = '2025-03-01'
  ANALYSIS_END_DATE = '2025-09-30'

  print(f"\n--- Collecting Half-Hourly Raw Purchase Metrics (Weekly Pulls) ---")
  print(f"Period: {ANALYSIS_START_DATE} to {ANALYSIS_END_DATE}")

  # --- Main Loop ---
  all_half_hourly_data = []
  current_week_start = datetime.strptime(ANALYSIS_START_DATE, '%Y-%m-%d')
  end_date_obj = datetime.strptime(ANALYSIS_END_DATE, '%Y-%m-%d')

  week_count = (end_date_obj - current_week_start).days // 7 + 1
  progress_bar = tqdm(total=week_count, desc="Processing weeks")

  while current_week_start < end_date_obj:
      current_week_end = current_week_start + timedelta(days=7)

      week_start_str = current_week_start.strftime('%Y-%m-%d 00:00:00')
      week_end_str = current_week_end.strftime('%Y-%m-%d 00:00:00')

      print(f"Processing week: {current_week_start.date()} to {current_week_end.date()}...")

      query = f"""
      SELECT
          -- Half-hourly time bucket
          DATEADD(MINUTE, FLOOR(EXTRACT(MINUTE FROM PURCHASED_AT)/30)*30, 
                  DATE_TRUNC('HOUR', PURCHASED_AT))::TIMESTAMP_NTZ AS activity_half_hour,

          -- Raw Aggregate Metrics
          COUNT(DISTINCT PURCHASE_ID) AS half_hourly_transaction_count,
          COALESCE(SUM(QUANTITY * UNIT_PRICE), 0) AS half_hourly_gmv,
          COALESCE(SUM(QUANTITY), 0) AS half_hourly_units_sold,
          COUNT(DISTINCT USER_ID) AS half_hourly_purchasing_users,
          COUNT(DISTINCT PRODUCT_ID) AS half_hourly_products_purchased,
          COUNT(*) AS half_hourly_total_purchase_lines,
          
          -- Price and transaction metrics
          COALESCE(AVG(QUANTITY * UNIT_PRICE), 0) AS half_hourly_avg_transaction_value,
          COALESCE(AVG(QUANTITY), 0) AS half_hourly_avg_units_per_line,
          COALESCE(AVG(UNIT_PRICE), 0) AS half_hourly_avg_unit_price,
          COALESCE(MIN(UNIT_PRICE), 0) AS half_hourly_min_unit_price,
          COALESCE(MAX(UNIT_PRICE), 0) AS half_hourly_max_unit_price,
          COALESCE(STDDEV(UNIT_PRICE), 0) AS half_hourly_stddev_unit_price,
          
          -- Quantity metrics
          COALESCE(MIN(QUANTITY), 0) AS half_hourly_min_quantity,
          COALESCE(MAX(QUANTITY), 0) AS half_hourly_max_quantity,
          COALESCE(STDDEV(QUANTITY), 0) AS half_hourly_stddev_quantity
      FROM
          PURCHASES
      WHERE
          PURCHASED_AT >= '{week_start_str}'::TIMESTAMP_NTZ
          AND PURCHASED_AT < '{week_end_str}'::TIMESTAMP_NTZ
      GROUP BY
          1
      ORDER BY
          1;
      """

      try:
          half_hourly_df_for_week = run_query(query)
          if not half_hourly_df_for_week.empty:
              all_half_hourly_data.append(half_hourly_df_for_week)
              print(f"   -> Success: Found {half_hourly_df_for_week.shape[0]} half-hourly records for the week.")
          else:
              print(f"   -> Info: No purchase data found for this week.")

      except Exception as e:
          print(f"   -> ERROR processing week starting {current_week_start.date()}: {e}")

      # Move to the next week
      current_week_start = current_week_end
      progress_bar.update(1)

  progress_bar.close()

  # --- Final Processing and Display ---
  if all_half_hourly_data:
      final_df = pd.concat(all_half_hourly_data, ignore_index=True)

      # Convert all numeric columns
      numeric_columns = [col for col in final_df.columns if col != 'ACTIVITY_HALF_HOUR']
      for col in numeric_columns:
          final_df[col] = pd.to_numeric(final_df[col])

      # --- SAVE TO PARQUET IN DATA FOLDER ---
      output_filename = f"data/half_hourly_purchases_{ANALYSIS_START_DATE}_to_{ANALYSIS_END_DATE}.parquet"
      final_df.to_parquet(output_filename, index=False)
      print(f"\n✅ Data successfully saved to {output_filename}")

      show_table(final_df.head(25), "Aggregated Half-Hourly Purchase Metrics")

      print(f"\nDataset Summary:")
      print(f"Total records: {final_df.shape[0]:,}")
      print(f"Total columns: {final_df.shape[1]}")
      print(f"Memory usage: {final_df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
  else:
      print("\nNo purchase data found for the entire specified period.")
# Out:
# --- Collecting Half-Hourly Raw Purchase Metrics (Weekly Pulls) ---
# Period: 2025-03-01 to 2025-09-30
# Processing weeks:  10%|▉         | 3/31 [03:41<34:31, 73.97s/it]
# Processing week: 2025-03-01 to 2025-03-08...
# Processing weeks:   3%|▎         | 1/31 [00:02<01:21,  2.71s/it]
#    -> Info: No purchase data found for this week.
# Processing week: 2025-03-08 to 2025-03-15...
# Processing weeks:   6%|▋         | 2/31 [00:04<01:00,  2.09s/it]
#    -> Success: Found 48 half-hourly records for the week.
# Processing week: 2025-03-15 to 2025-03-22...
# Processing weeks:  10%|▉         | 3/31 [00:07<01:11,  2.56s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-03-22 to 2025-03-29...
# Processing weeks:  13%|█▎        | 4/31 [00:11<01:22,  3.05s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-03-29 to 2025-04-05...
# Processing weeks:  16%|█▌        | 5/31 [00:14<01:23,  3.19s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-04-05 to 2025-04-12...
# Processing weeks:  19%|█▉        | 6/31 [00:17<01:20,  3.20s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-04-12 to 2025-04-19...
# Processing weeks:  23%|██▎       | 7/31 [00:22<01:28,  3.70s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-04-19 to 2025-04-26...
# Processing weeks:  26%|██▌       | 8/31 [00:27<01:36,  4.19s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-04-26 to 2025-05-03...
# Processing weeks:  29%|██▉       | 9/31 [00:33<01:38,  4.48s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-05-03 to 2025-05-10...
# Processing weeks:  32%|███▏      | 10/31 [00:37<01:31,  4.37s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-05-10 to 2025-05-17...
# Processing weeks:  35%|███▌      | 11/31 [00:40<01:21,  4.10s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-05-17 to 2025-05-24...
# Processing weeks:  39%|███▊      | 12/31 [00:44<01:16,  4.03s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-05-24 to 2025-05-31...
# Processing weeks:  42%|████▏     | 13/31 [00:47<01:04,  3.58s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-05-31 to 2025-06-07...
# Processing weeks:  45%|████▌     | 14/31 [00:51<01:07,  3.96s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-06-07 to 2025-06-14...
# Processing weeks:  48%|████▊     | 15/31 [00:54<00:54,  3.41s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-06-14 to 2025-06-21...
# Processing weeks:  52%|█████▏    | 16/31 [00:58<00:56,  3.75s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-06-21 to 2025-06-28...
# Processing weeks:  55%|█████▍    | 17/31 [01:04<00:59,  4.26s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-06-28 to 2025-07-05...
# Processing weeks:  58%|█████▊    | 18/31 [01:10<01:04,  4.99s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-07-05 to 2025-07-12...
# Processing weeks:  61%|██████▏   | 19/31 [01:18<01:10,  5.89s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-07-12 to 2025-07-19...
# Processing weeks:  65%|██████▍   | 20/31 [01:23<01:01,  5.58s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-07-19 to 2025-07-26...
# Processing weeks:  68%|██████▊   | 21/31 [01:28<00:52,  5.28s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-07-26 to 2025-08-02...
# Processing weeks:  71%|███████   | 22/31 [01:32<00:45,  5.09s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-08-02 to 2025-08-09...
# Processing weeks:  74%|███████▍  | 23/31 [01:39<00:44,  5.54s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-08-09 to 2025-08-16...
# Processing weeks:  77%|███████▋  | 24/31 [01:45<00:39,  5.61s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-08-16 to 2025-08-23...
# Processing weeks:  81%|████████  | 25/31 [01:51<00:34,  5.75s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-08-23 to 2025-08-30...
# Processing weeks:  84%|████████▍ | 26/31 [01:59<00:32,  6.48s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-08-30 to 2025-09-06...
# Processing weeks:  87%|████████▋ | 27/31 [02:08<00:28,  7.23s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-09-06 to 2025-09-13...
# Processing weeks:  90%|█████████ | 28/31 [02:17<00:22,  7.65s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-09-13 to 2025-09-20...
# Processing weeks:  97%|█████████▋| 30/31 [02:21<00:04,  4.66s/it]
#    -> Success: Found 191 half-hourly records for the week.
# Processing week: 2025-09-20 to 2025-09-27...
#    -> Info: No purchase data found for this week.
# Processing week: 2025-09-27 to 2025-10-04...
# Processing weeks: 100%|██████████| 31/31 [02:21<00:00,  4.58s/it]
#    -> Info: No purchase data found for this week.
#
# ✅ Data successfully saved to data/half_hourly_purchases_2025-03-01_to_2025-09-30.parquet
#
# Aggregated Half-Hourly Purchase Metrics
# =======================================
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | ACTIVITY_HALF_HOUR   |   HALF_HOURLY_TRANSACTION_COUNT |   HALF_HOURLY_GMV |   HALF_HOURLY_UNITS_SOLD |   HALF_HOURLY_PURCHASING_USERS |   HALF_HOURLY_PRODUCTS_PURCHASED |   HALF_HOURLY_TOTAL_PURCHASE_LINES |   HALF_HOURLY_AVG_TRANSACTION_VALUE |   HALF_HOURLY_AVG_UNITS_PER_LINE |   HALF_HOURLY_AVG_UNIT_PRICE |   HALF_HOURLY_MIN_UNIT_PRICE |   HALF_HOURLY_MAX_UNIT_PRICE |   HALF_HOURLY_STDDEV_UNIT_PRICE |   HALF_HOURLY_MIN_QUANTITY |   HALF_HOURLY_MAX_QUANTITY |   HALF_HOURLY_STDDEV_QUANTITY |
# +======================+=================================+===================+==========================+================================+==================================+====================================+=====================================+==================================+==============================+==============================+==============================+=================================+============================+============================+===============================+
# | 2025-03-14 00:00:00  |                            3337 |          15665600 |                     4256 |                           3070 |                             3782 |                               4256 |                             3680.83 |                                1 |                      3680.83 |                          300 |                       380000 |                         9702.76 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 00:30:00  |                            3310 |          13824200 |                     3992 |                           3028 |                             3755 |                               3992 |                             3462.98 |                                1 |                      3462.98 |                          300 |                       160000 |                         5573.44 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 01:00:00  |                            3469 |          15487600 |                     4889 |                           3218 |                             3988 |                               4889 |                             3167.85 |                                1 |                      3167.85 |                          300 |                       110000 |                         5862    |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 01:30:00  |                            3423 |          14537100 |                     4535 |                           3168 |                             3885 |                               4535 |                             3205.53 |                                1 |                      3205.53 |                          300 |                       170000 |                         6493.53 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 02:00:00  |                            3454 |          16208500 |                     4668 |                           3137 |                             3956 |                               4668 |                             3472.26 |                                1 |                      3472.26 |                          300 |                       461800 |                        12810.8  |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 02:30:00  |                            3270 |          17661585 |                     4540 |                           2928 |                             3689 |                               4540 |                             3890.22 |                                1 |                      3890.22 |                          300 |                       461800 |                        13865.2  |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 03:00:00  |                            2739 |          12617600 |                     3568 |                           2544 |                             3139 |                               3568 |                             3536.32 |                                1 |                      3536.32 |                          300 |                       230000 |                         7221.98 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 03:30:00  |                            2412 |          10619100 |                     3313 |                           2194 |                             2846 |                               3313 |                             3205.28 |                                1 |                      3205.28 |                          300 |                        70000 |                         4831.63 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 04:00:00  |                            2171 |          11933600 |                     3107 |                           1973 |                             2466 |                               3107 |                             3840.88 |                                1 |                      3840.88 |                          300 |                       445000 |                         9675.92 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 04:30:00  |                            1720 |           8109100 |                     2497 |                           1584 |                             1919 |                               2497 |                             3247.54 |                                1 |                      3247.54 |                          300 |                       150000 |                         6300.27 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 05:00:00  |                            1361 |           6462800 |                     2014 |                           1260 |                             1575 |                               2014 |                             3208.94 |                                1 |                      3208.94 |                          300 |                       147500 |                         6268.45 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 05:30:00  |                            1067 |           5091600 |                     1382 |                           1007 |                             1206 |                               1382 |                             3684.23 |                                1 |                      3684.23 |                          300 |                        55000 |                         4973.46 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 06:00:00  |                             864 |           4636900 |                     1377 |                            808 |                             1050 |                               1377 |                             3367.39 |                                1 |                      3367.39 |                          300 |                       200000 |                         8222.56 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 06:30:00  |                             709 |           3362200 |                     1034 |                            649 |                              849 |                               1034 |                             3251.64 |                                1 |                      3251.64 |                          300 |                       300000 |                        10093.9  |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 07:00:00  |                             775 |           7129300 |                     1269 |                            704 |                              877 |                               1269 |                             5618.05 |                                1 |                      5618.05 |                          300 |                       250000 |                        12042.6  |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 07:30:00  |                             775 |           4778000 |                     1090 |                            670 |                              786 |                               1090 |                             4383.49 |                                1 |                      4383.49 |                          300 |                        82500 |                         6800.17 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 08:00:00  |                             492 |           3956000 |                      659 |                            460 |                              502 |                                659 |                             6003.03 |                                1 |                      6003.03 |                          300 |                       134900 |                        12873.5  |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 08:30:00  |                             598 |           2480900 |                      916 |                            545 |                              631 |                                916 |                             2708.41 |                                1 |                      2708.41 |                          300 |                        60000 |                         4296.3  |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 09:00:00  |                             562 |           2402900 |                      692 |                            527 |                              671 |                                692 |                             3472.4  |                                1 |                      3472.4  |                          300 |                       105900 |                         5793.57 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 09:30:00  |                             741 |           3090600 |                     1283 |                            704 |                             1087 |                               1283 |                             2408.89 |                                1 |                      2408.89 |                          300 |                       129500 |                         5987.23 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 10:00:00  |                             873 |           3437800 |                     1044 |                            836 |                             1035 |                               1044 |                             3292.91 |                                1 |                      3292.91 |                          300 |                        85000 |                         4749.33 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 10:30:00  |                            1161 |           4611300 |                     1378 |                           1084 |                             1329 |                               1378 |                             3346.37 |                                1 |                      3346.37 |                          300 |                        99900 |                         5249.75 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 11:00:00  |                            1551 |           6661200 |                     1794 |                           1461 |                             1778 |                               1794 |                             3713.04 |                                1 |                      3713.04 |                          300 |                       150000 |                         6765.37 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 11:30:00  |                            1815 |           7903000 |                     2085 |                           1715 |                             2054 |                               2085 |                             3790.41 |                                1 |                      3790.41 |                          300 |                       140000 |                         7672.63 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
# | 2025-03-14 12:00:00  |                            2066 |           8572600 |                     2337 |                           1940 |                             2317 |                               2337 |                             3668.21 |                                1 |                      3668.21 |                          300 |                       185000 |                         7248.65 |                          1 |                          1 |                             0 |
# +----------------------+---------------------------------+-------------------+--------------------------+--------------------------------+----------------------------------+------------------------------------+-------------------------------------+----------------------------------+------------------------------+------------------------------+------------------------------+---------------------------------+----------------------------+----------------------------+-------------------------------+
#
# Dataset Summary:
# Total records: 8,975
# Total columns: 16
# Memory usage: 1.10 MB

# %% [markdown]
# # clicks

# %%
# --- CONFIGURATION ---
ANALYSIS_START_DATE = '2025-03-01'
ANALYSIS_END_DATE = '2025-09-30'

print(f"\n--- Collecting Half-Hourly Raw Click Metrics (Weekly Pulls) ---")
print(f"Period: {ANALYSIS_START_DATE} to {ANALYSIS_END_DATE}")

# --- Main Loop ---
all_half_hourly_data = []
current_week_start = datetime.strptime(ANALYSIS_START_DATE, '%Y-%m-%d')
end_date_obj = datetime.strptime(ANALYSIS_END_DATE, '%Y-%m-%d')

week_count = (end_date_obj - current_week_start).days // 7 + 1
progress_bar = tqdm(total=week_count, desc="Processing weeks")

while current_week_start < end_date_obj:
    current_week_end = current_week_start + timedelta(days=7)

    week_start_str = current_week_start.strftime('%Y-%m-%d 00:00:00')
    week_end_str = current_week_end.strftime('%Y-%m-%d 00:00:00')

    print(f"Processing week: {current_week_start.date()} to {current_week_end.date()}...")

    query = f"""
    SELECT
        -- Half-hourly time bucket
        DATEADD(MINUTE, FLOOR(EXTRACT(MINUTE FROM OCCURRED_AT)/30)*30, 
                DATE_TRUNC('HOUR', OCCURRED_AT))::TIMESTAMP_NTZ AS activity_half_hour,

        -- Raw Aggregate Metrics
        COUNT(INTERACTION_ID) AS half_hourly_click_count,
        COUNT(DISTINCT USER_ID) AS half_hourly_clicking_users,
        COUNT(DISTINCT VENDOR_ID) AS half_hourly_clicked_vendors,
        COUNT(DISTINCT CAMPAIGN_ID) AS half_hourly_clicked_campaigns,
        COUNT(DISTINCT PRODUCT_ID) AS half_hourly_clicked_products,
        COUNT(DISTINCT AUCTION_ID) AS half_hourly_clicked_auctions,
        
        -- Engagement intensity metrics
        COUNT(DISTINCT CONCAT(USER_ID, '_', VENDOR_ID)) AS half_hourly_user_vendor_pairs,
        COUNT(DISTINCT CONCAT(USER_ID, '_', PRODUCT_ID)) AS half_hourly_user_product_pairs,
        COUNT(DISTINCT CONCAT(VENDOR_ID, '_', PRODUCT_ID)) AS half_hourly_vendor_product_pairs,
        COUNT(DISTINCT CONCAT(CAMPAIGN_ID, '_', PRODUCT_ID)) AS half_hourly_campaign_product_pairs,
        COUNT(DISTINCT CONCAT(USER_ID, '_', CAMPAIGN_ID)) AS half_hourly_user_campaign_pairs
    FROM
        CLICKS
    WHERE
        OCCURRED_AT >= '{week_start_str}'::TIMESTAMP_NTZ
        AND OCCURRED_AT < '{week_end_str}'::TIMESTAMP_NTZ
    GROUP BY
        1
    ORDER BY
        1;
    """

    try:
        half_hourly_df_for_week = run_query(query)
        if not half_hourly_df_for_week.empty:
            all_half_hourly_data.append(half_hourly_df_for_week)
            print(f"   -> Success: Found {half_hourly_df_for_week.shape[0]} half-hourly records for the week.")
        else:
            print(f"   -> Info: No click data found for this week.")

    except Exception as e:
        print(f"   -> ERROR processing week starting {current_week_start.date()}: {e}")

    # Move to the next week
    current_week_start = current_week_end
    progress_bar.update(1)

progress_bar.close()

# --- Final Processing and Display ---
if all_half_hourly_data:
    final_df = pd.concat(all_half_hourly_data, ignore_index=True)

    # Convert all numeric columns
    numeric_columns = [col for col in final_df.columns if col != 'ACTIVITY_HALF_HOUR']
    for col in numeric_columns:
        final_df[col] = pd.to_numeric(final_df[col])

    # --- SAVE TO PARQUET IN DATA FOLDER ---
    output_filename = f"data/half_hourly_clicks_{ANALYSIS_START_DATE}_to_{ANALYSIS_END_DATE}.parquet"
    final_df.to_parquet(output_filename, index=False)
    print(f"\n✅ Data successfully saved to {output_filename}")

    show_table(final_df.head(25), "Aggregated Half-Hourly Click Metrics")

    print(f"\nDataset Summary:")
    print(f"Total records: {final_df.shape[0]:,}")
    print(f"Total columns: {final_df.shape[1]}")
    print(f"Memory usage: {final_df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
else:
    print("\nNo click data found for the entire specified period.")
# Out:
# --- Collecting Half-Hourly Raw Click Metrics (Weekly Pulls) ---
# Period: 2025-03-01 to 2025-09-30
# Processing weeks:   0%|          | 0/31 [00:00<?, ?it/s]
# Processing week: 2025-03-01 to 2025-03-08...
# Processing weeks:   3%|▎         | 1/31 [00:03<01:43,  3.47s/it]
#    -> Info: No click data found for this week.
# Processing week: 2025-03-08 to 2025-03-15...
# Processing weeks:   6%|▋         | 2/31 [00:09<02:24,  5.00s/it]
#    -> Success: Found 48 half-hourly records for the week.
# Processing week: 2025-03-15 to 2025-03-22...
# Processing weeks:  10%|▉         | 3/31 [00:21<03:45,  8.07s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-03-22 to 2025-03-29...
# Processing weeks:  13%|█▎        | 4/31 [00:34<04:27,  9.91s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-03-29 to 2025-04-05...
# Processing weeks:  16%|█▌        | 5/31 [00:47<04:53, 11.28s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-04-05 to 2025-04-12...
# Processing weeks:  19%|█▉        | 6/31 [01:02<05:13, 12.55s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-04-12 to 2025-04-19...
# Processing weeks:  23%|██▎       | 7/31 [01:39<08:10, 20.43s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-04-19 to 2025-04-26...
# Processing weeks:  26%|██▌       | 8/31 [02:16<09:55, 25.89s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-04-26 to 2025-05-03...
# Processing weeks:  29%|██▉       | 9/31 [02:33<08:27, 23.07s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-05-03 to 2025-05-10...
# Processing weeks:  32%|███▏      | 10/31 [02:52<07:33, 21.62s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-05-10 to 2025-05-17...
# Processing weeks:  35%|███▌      | 11/31 [03:39<09:51, 29.58s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-05-17 to 2025-05-24...
# Processing weeks:  39%|███▊      | 12/31 [04:22<10:37, 33.57s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-05-24 to 2025-05-31...
# Processing weeks:  42%|████▏     | 13/31 [04:46<09:14, 30.81s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-05-31 to 2025-06-07...
# Processing weeks:  45%|████▌     | 14/31 [05:33<10:02, 35.43s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-06-07 to 2025-06-14...
# Processing weeks:  48%|████▊     | 15/31 [06:02<08:58, 33.64s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-06-14 to 2025-06-21...
# Processing weeks:  52%|█████▏    | 16/31 [06:23<07:26, 29.80s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-06-21 to 2025-06-28...
# Processing weeks:  55%|█████▍    | 17/31 [06:44<06:18, 27.05s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-06-28 to 2025-07-05...
# Processing weeks:  58%|█████▊    | 18/31 [07:05<05:28, 25.24s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-07-05 to 2025-07-12...
# Processing weeks:  61%|██████▏   | 19/31 [07:52<06:21, 31.78s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-07-12 to 2025-07-19...
# Processing weeks:  65%|██████▍   | 20/31 [08:39<06:41, 36.52s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-07-19 to 2025-07-26...
# Processing weeks:  68%|██████▊   | 21/31 [09:02<05:25, 32.51s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-07-26 to 2025-08-02...
# Processing weeks:  71%|███████   | 22/31 [09:53<05:40, 37.80s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-08-02 to 2025-08-09...
# Processing weeks:  74%|███████▍  | 23/31 [10:42<05:31, 41.44s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-08-09 to 2025-08-16...
# Processing weeks:  77%|███████▋  | 24/31 [11:30<05:02, 43.21s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-08-16 to 2025-08-23...
# Processing weeks:  81%|████████  | 25/31 [12:19<04:29, 44.91s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-08-23 to 2025-08-30...
# Processing weeks:  84%|████████▍ | 26/31 [12:43<03:13, 38.80s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-08-30 to 2025-09-06...
# Processing weeks:  87%|████████▋ | 27/31 [13:37<02:52, 43.22s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-09-06 to 2025-09-13...
# Processing weeks:  90%|█████████ | 28/31 [14:13<02:03, 41.08s/it]
#    -> Success: Found 336 half-hourly records for the week.
# Processing week: 2025-09-13 to 2025-09-20...
# Processing weeks:  94%|█████████▎| 29/31 [14:27<01:06, 33.16s/it]
#    -> Success: Found 191 half-hourly records for the week.
# Processing week: 2025-09-20 to 2025-09-27...
# Processing weeks:  97%|█████████▋| 30/31 [14:28<00:23, 23.41s/it]
#    -> Info: No click data found for this week.
# Processing week: 2025-09-27 to 2025-10-04...
# Processing weeks: 100%|██████████| 31/31 [14:29<00:00, 28.04s/it]
#    -> Info: No click data found for this week.
#
# ✅ Data successfully saved to data/half_hourly_clicks_2025-03-01_to_2025-09-30.parquet
#
# Aggregated Half-Hourly Click Metrics
# ====================================
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | ACTIVITY_HALF_HOUR   |   HALF_HOURLY_CLICK_COUNT |   HALF_HOURLY_CLICKING_USERS |   HALF_HOURLY_CLICKED_VENDORS |   HALF_HOURLY_CLICKED_CAMPAIGNS |   HALF_HOURLY_CLICKED_PRODUCTS |   HALF_HOURLY_CLICKED_AUCTIONS |   HALF_HOURLY_USER_VENDOR_PAIRS |   HALF_HOURLY_USER_PRODUCT_PAIRS |   HALF_HOURLY_VENDOR_PRODUCT_PAIRS |   HALF_HOURLY_CAMPAIGN_PRODUCT_PAIRS |   HALF_HOURLY_USER_CAMPAIGN_PAIRS |
# +======================+===========================+==============================+===============================+=================================+================================+================================+=================================+==================================+====================================+======================================+===================================+
# | 2025-03-14 00:00:00  |                     14956 |                         7714 |                          8417 |                            8417 |                          13115 |                          10327 |                           13275 |                            13681 |                              13115 |                                13115 |                             13275 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 00:30:00  |                     15654 |                         8078 |                          8535 |                            8536 |                          13624 |                          10780 |                           13816 |                            14287 |                              13624 |                                13624 |                             13816 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 01:00:00  |                     10782 |                         6276 |                          4606 |                            4606 |                           9028 |                           7849 |                            9580 |                             9929 |                               9028 |                                 9028 |                              9580 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 01:30:00  |                      8971 |                         5431 |                          3228 |                            3228 |                           7264 |                           6669 |                            7851 |                             8247 |                               7264 |                                 7264 |                              7851 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 02:00:00  |                      7668 |                         4861 |                          2791 |                            2791 |                           6125 |                           5876 |                            6751 |                             6989 |                               6125 |                                 6125 |                              6751 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 02:30:00  |                      6885 |                         4381 |                          2410 |                            2411 |                           5474 |                           5279 |                            6005 |                             6206 |                               5474 |                                 5474 |                              6005 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 03:00:00  |                      5332 |                         3561 |                          1972 |                            1972 |                           4293 |                           4180 |                            4704 |                             4893 |                               4293 |                                 4293 |                              4704 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 03:30:00  |                      5009 |                         3301 |                          1738 |                            1738 |                           4065 |                           3942 |                            4396 |                             4592 |                               4065 |                                 4065 |                              4396 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 04:00:00  |                      4055 |                         2716 |                          1524 |                            1524 |                           3341 |                           3239 |                            3602 |                             3744 |                               3341 |                                 3341 |                              3602 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 04:30:00  |                      3840 |                         2522 |                          1312 |                            1312 |                           3141 |                           3037 |                            3355 |                             3525 |                               3141 |                                 3141 |                              3355 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 05:00:00  |                      2521 |                         1708 |                          1121 |                            1121 |                           2080 |                           2019 |                            2210 |                             2292 |                               2080 |                                 2080 |                              2210 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 05:30:00  |                      1916 |                         1310 |                           953 |                             953 |                           1628 |                           1537 |                            1684 |                             1757 |                               1628 |                                 1628 |                              1684 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 06:00:00  |                      1594 |                         1063 |                           880 |                             880 |                           1355 |                           1249 |                            1395 |                             1456 |                               1355 |                                 1355 |                              1395 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 06:30:00  |                      2940 |                         1679 |                           727 |                             728 |                           2397 |                           2169 |                            2526 |                             2680 |                               2397 |                                 2397 |                              2526 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 07:00:00  |                      2314 |                         1317 |                           791 |                             791 |                           1965 |                           1733 |                            1983 |                             2083 |                               1965 |                                 1965 |                              1983 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 07:30:00  |                      1566 |                          941 |                           770 |                             770 |                           1372 |                           1192 |                            1365 |                             1432 |                               1372 |                                 1372 |                              1365 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 08:00:00  |                      3350 |                         1480 |                          2083 |                            2083 |                           2938 |                           2084 |                            2878 |                             3003 |                               2938 |                                 2938 |                              2878 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 08:30:00  |                      7024 |                         2460 |                          4363 |                            4363 |                           6042 |                           3863 |                            5997 |                             6207 |                               6042 |                                 6042 |                              5997 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 09:00:00  |                      6962 |                         2453 |                          4449 |                            4449 |                           6042 |                           3814 |                            5962 |                             6156 |                               6042 |                                 6042 |                              5962 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 09:30:00  |                      7226 |                         2568 |                          4643 |                            4643 |                           6293 |                           4025 |                            6208 |                             6442 |                               6293 |                                 6293 |                              6208 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 10:00:00  |                      7902 |                         3031 |                          5119 |                            5119 |                           6980 |                           4519 |                            6913 |                             7125 |                               6980 |                                 6980 |                              6913 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 10:30:00  |                      8915 |                         3563 |                          5607 |                            5607 |                           7763 |                           5239 |                            7663 |                             7913 |                               7763 |                                 7763 |                              7663 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 11:00:00  |                      9860 |                         4113 |                          6213 |                            6213 |                           8654 |                           5856 |                            8570 |                             8847 |                               8654 |                                 8654 |                              8570 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 11:30:00  |                     11291 |                         4691 |                          6829 |                            6830 |                           9893 |                           6671 |                            9777 |                            10108 |                               9893 |                                 9893 |                              9777 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
# | 2025-03-14 12:00:00  |                     11520 |                         5027 |                          7029 |                            7029 |                          10145 |                           7105 |                           10072 |                            10363 |                              10145 |                                10145 |                             10072 |
# +----------------------+---------------------------+------------------------------+-------------------------------+---------------------------------+--------------------------------+--------------------------------+---------------------------------+----------------------------------+------------------------------------+--------------------------------------+-----------------------------------+
#
# Dataset Summary:
# Total records: 8,975
# Total columns: 12
# Memory usage: 0.82 MB

# %% [markdown]
# # impressions

# %%
# --- CONFIGURATION ---
ANALYSIS_START_DATE = '2025-03-01'
ANALYSIS_END_DATE = '2025-09-30'

print(f"\n--- Collecting Half-Hourly Raw Impression Metrics (Weekly Pulls) ---")
print(f"Period: {ANALYSIS_START_DATE} to {ANALYSIS_END_DATE}")

# --- Main Loop ---
all_half_hourly_data = []
current_week_start = datetime.strptime(ANALYSIS_START_DATE, '%Y-%m-%d')
end_date_obj = datetime.strptime(ANALYSIS_END_DATE, '%Y-%m-%d')

week_count = (end_date_obj - current_week_start).days // 7 + 1
progress_bar = tqdm(total=week_count, desc="Processing weeks")

while current_week_start < end_date_obj:
    current_week_end = current_week_start + timedelta(days=7)

    week_start_str = current_week_start.strftime('%Y-%m-%d 00:00:00')
    week_end_str = current_week_end.strftime('%Y-%m-%d 00:00:00')

    print(f"Processing week: {current_week_start.date()} to {current_week_end.date()}...")

    query = f"""
    SELECT
        -- Half-hourly time bucket
        DATEADD(MINUTE, FLOOR(EXTRACT(MINUTE FROM OCCURRED_AT)/30)*30, 
                DATE_TRUNC('HOUR', OCCURRED_AT))::TIMESTAMP_NTZ AS activity_half_hour,

        -- Raw Aggregate Metrics
        COUNT(INTERACTION_ID) AS half_hourly_impression_count,
        COUNT(DISTINCT USER_ID) AS half_hourly_impressed_users,
        COUNT(DISTINCT VENDOR_ID) AS half_hourly_impressed_vendors,
        COUNT(DISTINCT CAMPAIGN_ID) AS half_hourly_impressed_campaigns,
        COUNT(DISTINCT PRODUCT_ID) AS half_hourly_impressed_products,
        COUNT(DISTINCT AUCTION_ID) AS half_hourly_impressed_auctions,
        
        -- Concentration metrics
        COUNT(DISTINCT CONCAT(USER_ID, '_', VENDOR_ID)) AS half_hourly_user_vendor_pairs,
        COUNT(DISTINCT CONCAT(USER_ID, '_', PRODUCT_ID)) AS half_hourly_user_product_pairs,
        COUNT(DISTINCT CONCAT(VENDOR_ID, '_', PRODUCT_ID)) AS half_hourly_vendor_product_pairs,
        COUNT(DISTINCT CONCAT(CAMPAIGN_ID, '_', PRODUCT_ID)) AS half_hourly_campaign_product_pairs
    FROM
        IMPRESSIONS
    WHERE
        OCCURRED_AT >= '{week_start_str}'::TIMESTAMP_NTZ
        AND OCCURRED_AT < '{week_end_str}'::TIMESTAMP_NTZ
    GROUP BY
        1
    ORDER BY
        1;
    """

    try:
        half_hourly_df_for_week = run_query(query)
        if not half_hourly_df_for_week.empty:
            all_half_hourly_data.append(half_hourly_df_for_week)
            print(f"   -> Success: Found {half_hourly_df_for_week.shape[0]} half-hourly records for the week.")
        else:
            print(f"   -> Info: No impression data found for this week.")

    except Exception as e:
        print(f"   -> ERROR processing week starting {current_week_start.date()}: {e}")

    # Move to the next week
    current_week_start = current_week_end
    progress_bar.update(1)

progress_bar.close()

# --- Final Processing and Display ---
if all_half_hourly_data:
    final_df = pd.concat(all_half_hourly_data, ignore_index=True)

    # Convert all numeric columns
    numeric_columns = [col for col in final_df.columns if col != 'ACTIVITY_HALF_HOUR']
    for col in numeric_columns:
        final_df[col] = pd.to_numeric(final_df[col])

    # --- SAVE TO PARQUET IN DATA FOLDER ---
    output_filename = f"data/half_hourly_impressions_{ANALYSIS_START_DATE}_to_{ANALYSIS_END_DATE}.parquet"
    final_df.to_parquet(output_filename, index=False)
    print(f"\n✅ Data successfully saved to {output_filename}")

    show_table(final_df.head(25), "Aggregated Half-Hourly Impression Metrics")

    print(f"\nDataset Summary:")
    print(f"Total records: {final_df.shape[0]:,}")
    print(f"Total columns: {final_df.shape[1]}")
    print(f"Memory usage: {final_df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
else:
    print("\nNo impression data found for the entire specified period.")
# Out:
# --- Collecting Half-Hourly Raw Impression Metrics (Weekly Pulls) ---
# Period: 2025-03-01 to 2025-09-30
# Processing remaining weeks:   3%|▎         | 1/31 [12:12<6:06:24, 732.82s/it]
# Processing week: 2025-03-01 to 2025-03-08...
#    -> Info: No impression data found for this week.
# Processing week: 2025-03-08 to 2025-03-15...
#    -> Success: Found 48 half-hourly records for the week.
# Processing week: 2025-03-15 to 2025-03-22...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 55
#      24 query = f"""
#      25 SELECT
#      26     -- Half-hourly time bucket
#    (...)     51     1;
#      52 """
#      54 try:
# ---> 55     half_hourly_df_for_week = run_query(query)
#      56     if not half_hourly_df_for_week.empty:
#      57         all_half_hourly_data.append(half_hourly_df_for_week)
#
# Cell In[1], line 28, in run_query(query)
#      26 def run_query(query):
#      27     try:
# ---> 28         cursor.execute(query)
#      29         if cursor.description:
#      30             results = cursor.fetchall()
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/cursor.py:1023, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _force_qmark_paramstyle, _dataframe_ast)
#    1016     logger.debug(
#    1017         "query was rewritten: org=%s, new=%s",
#    1018         " ".join(line.strip() for line in query.split("\n")),
#    1019         query1,
#    1020     )
#    1021     query = query1
# -> 1023 ret = self._execute_helper(query, **kwargs)
#    1024 self._sfqid = (
#    1025     ret["data"]["queryId"]
#    1026     if "data" in ret and "queryId" in ret["data"]
#    1027     else None
#    1028 )
#    1029 logger.debug(f"sfqid: {self.sfqid}")
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/cursor.py:729, in SnowflakeCursor._execute_helper(self, query, timeout, statement_params, binding_params, binding_stage, is_internal, describe_only, _no_results, _is_put_get, _no_retry, dataframe_ast)
#     727 ret: dict[str, Any] = {"data": {}}
#     728 try:
# --> 729     ret = self._connection.cmd_query(
#     730         query,
#     731         self._sequence_counter,
#     732         self._request_id,
#     733         binding_params=binding_params,
#     734         binding_stage=binding_stage,
#     735         is_file_transfer=bool(self._is_file_transfer),
#     736         statement_params=statement_params,
#     737         is_internal=is_internal,
#     738         describe_only=describe_only,
#     739         _no_results=_no_results,
#     740         _no_retry=_no_retry,
#     741         timeout=real_timeout,
#     742         dataframe_ast=dataframe_ast,
#     743     )
#     744 finally:
#     745     try:
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/connection.py:1668, in SnowflakeConnection.cmd_query(self, sql, sequence_counter, request_id, binding_params, binding_stage, is_file_transfer, statement_params, is_internal, describe_only, _no_results, _update_current_object, _no_retry, timeout, dataframe_ast)
#    1659     logger.debug(
#    1660         "sql=[%s], sequence_id=[%s], is_file_transfer=[%s]",
#    1661         self._format_query_for_log(data["sqlText"]),
#    1662         data["sequenceId"],
#    1663         is_file_transfer,
#    1664     )
#    1666 url_parameters = {REQUEST_ID: request_id}
# -> 1668 ret = self.rest.request(
#    1669     "/queries/v1/query-request?" + urlencode(url_parameters),
#    1670     data,
#    1671     client=client,
#    1672     _no_results=_no_results,
#    1673     _include_retry_params=True,
#    1674     _no_retry=_no_retry,
#    1675     timeout=timeout,
#    1676 )
#    1678 if ret is None:
#    1679     ret = {"data": {}}
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/network.py:461, in SnowflakeRestful.request(self, url, body, method, client, timeout, _no_results, _include_retry_params, _no_retry)
#     459     headers[HTTP_HEADER_SERVICE_NAME] = self._connection.service_name
#     460 if method == "post":
# --> 461     return self._post_request(
#     462         url,
#     463         headers,
#     464         json.dumps(body, cls=SnowflakeRestfulJsonEncoder),
#     465         token=self.token,
#     466         external_session_id=self.external_session_id,
#     467         _no_results=_no_results,
#     468         timeout=timeout,
#     469         _include_retry_params=_include_retry_params,
#     470         no_retry=_no_retry,
#     471     )
#     472 else:
#     473     return self._get_request(
#     474         url,
#     475         headers,
#    (...)    478         timeout=timeout,
#     479     )
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/network.py:728, in SnowflakeRestful._post_request(self, url, headers, body, token, external_session_id, timeout, socket_timeout, _no_results, no_retry, _include_retry_params)
#     725     ret = probe_connection(full_url)
#     726     pprint(ret)
# --> 728 ret = self.fetch(
#     729     "post",
#     730     full_url,
#     731     headers,
#     732     data=body,
#     733     timeout=timeout,
#     734     token=token,
#     735     external_session_id=external_session_id,
#     736     no_retry=no_retry,
#     737     _include_retry_params=_include_retry_params,
#     738     socket_timeout=socket_timeout,
#     739 )
#     740 logger.debug(
#     741     "ret[code] = {code}, after post request".format(
#     742         code=(ret.get("code", "N/A"))
#     743     )
#     744 )
#     746 if ret.get("code") == MASTER_TOKEN_EXPIRED_GS_CODE:
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/network.py:847, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     845 retry_ctx.set_start_time()
#     846 while True:
# --> 847     ret = self._request_exec_wrapper(
#     848         session, method, full_url, headers, data, retry_ctx, **kwargs
#     849     )
#     850     if ret is not None:
#     851         return ret
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/network.py:898, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, external_session_id, **kwargs)
#     896 raise_raw_http_failure = kwargs.pop("raise_raw_http_failure", False)
#     897 try:
# --> 898     return_object = self._request_exec(
#     899         session=session,
#     900         method=method,
#     901         full_url=full_url,
#     902         headers=headers,
#     903         data=data,
#     904         token=token,
#     905         external_session_id=external_session_id,
#     906         raise_raw_http_failure=raise_raw_http_failure,
#     907         **kwargs,
#     908     )
#     909     if return_object is not None:
#     910         return return_object
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/network.py:1083, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, external_session_id, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication, raise_raw_http_failure)
#    1075 # socket timeout is constant. You should be able to receive
#    1076 # the response within the time. If not, ConnectReadTimeout or
#    1077 # ReadTimeout is raised.
#    1078 auth = (
#    1079     PATWithExternalSessionAuth(token, external_session_id)
#    1080     if (external_session_id is not None and token is not None)
#    1081     else SnowflakeAuth(token)
#    1082 )
# -> 1083 raw_ret = session.request(
#    1084     method=method,
#    1085     url=full_url,
#    1086     headers=headers,
#    1087     data=input_data,
#    1088     timeout=socket_timeout,
#    1089     verify=True,
#    1090     stream=is_raw_binary,
#    1091     auth=auth,
#    1092 )
#    1093 download_end_time = get_time_millis()
#    1095 try:
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/vendored/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/vendored/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/vendored/requests/adapters.py:485, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     482     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     484 try:
# --> 485     resp = conn.urlopen(
#     486         method=request.method,
#     487         url=url,
#     488         body=request.body,
#     489         headers=request.headers,
#     490         redirect=False,
#     491         assert_same_host=False,
#     492         preload_content=False,
#     493         decode_content=False,
#     494         retries=self.max_retries,
#     495         timeout=timeout,
#     496         chunked=chunked,
#     497     )
#     499 except (ProtocolError, OSError) as err:
#     500     raise ConnectionError(err, request=request)
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/vendored/urllib3/contrib/pyopenssl.py:330, in WrappedSocket.recv_into(self, *args, **kwargs)
#     328         raise
#     329 except OpenSSL.SSL.WantReadError:
# --> 330     if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     331         raise timeout("The read operation timed out")
#     332     else:
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:145, in wait_for_read(sock, timeout)
#     141 def wait_for_read(sock, timeout=None):
#     142     """Waits for reading to be available on a given socket.
#     143     Returns True if the socket is readable, or False if the timeout expired.
#     144     """
# --> 145     return wait_for_socket(sock, read=True, timeout=timeout)
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:106, in poll_wait_for_socket(sock, read, write, timeout)
#     103         t *= 1000
#     104     return poll_obj.poll(t)
# --> 106 return bool(_retry_on_intr(do_poll, timeout))
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:43, in _retry_on_intr(fn, timeout)
#      42 def _retry_on_intr(fn, timeout):
# ---> 43     return fn(timeout)
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:104, in poll_wait_for_socket.<locals>.do_poll(t)
#     102 if t is not None:
#     103     t *= 1000
# --> 104 return poll_obj.poll(t)
#
# File ~/Code/marketplace-incrementality/venv/lib/python3.13/site-packages/snowflake/connector/cursor.py:718, in SnowflakeCursor._execute_helper.<locals>.interrupt_handler(*_)
#     715         except (ValueError, TypeError):
#     716             # ignore failures
#     717             pass
# --> 718 raise KeyboardInterrupt
#
# KeyboardInterrupt:

# %% [markdown]
# # auctions - users

# %%
# --- CONFIGURATION ---
ANALYSIS_START_DATE = '2025-03-01'
ANALYSIS_END_DATE = '2025-09-30'

print(f"\n--- Collecting Half-Hourly Raw Auction User Metrics (Weekly Pulls) ---")
print(f"Period: {ANALYSIS_START_DATE} to {ANALYSIS_END_DATE}")

# --- Main Loop ---
all_half_hourly_data = []
current_week_start = datetime.strptime(ANALYSIS_START_DATE, '%Y-%m-%d')
end_date_obj = datetime.strptime(ANALYSIS_END_DATE, '%Y-%m-%d')

week_count = (end_date_obj - current_week_start).days // 7 + 1
progress_bar = tqdm(total=week_count, desc="Processing weeks")

while current_week_start < end_date_obj:
    current_week_end = current_week_start + timedelta(days=7)

    week_start_str = current_week_start.strftime('%Y-%m-%d 00:00:00')
    week_end_str = current_week_end.strftime('%Y-%m-%d 00:00:00')

    print(f"Processing week: {current_week_start.date()} to {current_week_end.date()}...")

    query = f"""
    SELECT
        -- Half-hourly time bucket
        DATEADD(MINUTE, FLOOR(EXTRACT(MINUTE FROM CREATED_AT)/30)*30, 
                DATE_TRUNC('HOUR', CREATED_AT))::TIMESTAMP_NTZ AS activity_half_hour,

        -- Auction metrics
        COUNT(AUCTION_ID) AS half_hourly_auction_count,
        COUNT(DISTINCT AUCTION_ID) AS half_hourly_unique_auctions,
        COUNT(DISTINCT OPAQUE_USER_ID) AS half_hourly_auction_users,
        
        -- User activity intensity
        COALESCE(AVG(user_auction_counts.auctions_per_user), 0) AS half_hourly_avg_auctions_per_user,
        COALESCE(MIN(user_auction_counts.auctions_per_user), 0) AS half_hourly_min_auctions_per_user,
        COALESCE(MAX(user_auction_counts.auctions_per_user), 0) AS half_hourly_max_auctions_per_user,
        COALESCE(STDDEV(user_auction_counts.auctions_per_user), 0) AS half_hourly_stddev_auctions_per_user
    FROM
        AUCTIONS_USERS au
    LEFT JOIN (
        SELECT 
            OPAQUE_USER_ID,
            DATEADD(MINUTE, FLOOR(EXTRACT(MINUTE FROM CREATED_AT)/30)*30, 
                    DATE_TRUNC('HOUR', CREATED_AT))::TIMESTAMP_NTZ AS half_hour_bucket,
            COUNT(AUCTION_ID) AS auctions_per_user
        FROM AUCTIONS_USERS
        WHERE CREATED_AT >= '{week_start_str}'::TIMESTAMP_NTZ
        AND CREATED_AT < '{week_end_str}'::TIMESTAMP_NTZ
        GROUP BY OPAQUE_USER_ID, half_hour_bucket
    ) user_auction_counts ON au.OPAQUE_USER_ID = user_auction_counts.OPAQUE_USER_ID 
                        AND DATEADD(MINUTE, FLOOR(EXTRACT(MINUTE FROM au.CREATED_AT)/30)*30, 
                                    DATE_TRUNC('HOUR', au.CREATED_AT))::TIMESTAMP_NTZ = user_auction_counts.half_hour_bucket
    WHERE
        au.CREATED_AT >= '{week_start_str}'::TIMESTAMP_NTZ
        AND au.CREATED_AT < '{week_end_str}'::TIMESTAMP_NTZ
    GROUP BY
        1
    ORDER BY
        1;
    """

    try:
        half_hourly_df_for_week = run_query(query)
        if not half_hourly_df_for_week.empty:
            all_half_hourly_data.append(half_hourly_df_for_week)
            print(f"   -> Success: Found {half_hourly_df_for_week.shape[0]} half-hourly records for the week.")
        else:
            print(f"   -> Info: No auction user data found for this week.")

    except Exception as e:
        print(f"   -> ERROR processing week starting {current_week_start.date()}: {e}")

    # Move to the next week
    current_week_start = current_week_end
    progress_bar.update(1)

progress_bar.close()

# --- Final Processing and Display ---
if all_half_hourly_data:
    final_df = pd.concat(all_half_hourly_data, ignore_index=True)

    # Convert all numeric columns
    numeric_columns = [col for col in final_df.columns if col != 'ACTIVITY_HALF_HOUR']
    for col in numeric_columns:
        final_df[col] = pd.to_numeric(final_df[col])

    # --- SAVE TO PARQUET IN DATA FOLDER ---
    output_filename = f"data/half_hourly_auction_users_{ANALYSIS_START_DATE}_to_{ANALYSIS_END_DATE}.parquet"
    final_df.to_parquet(output_filename, index=False)
    print(f"\n✅ Data successfully saved to {output_filename}")

    show_table(final_df.head(25), "Aggregated Half-Hourly Auction User Metrics")

    print(f"\nDataset Summary:")
    print(f"Total records: {final_df.shape[0]:,}")
    print(f"Total columns: {final_df.shape[1]}")
    print(f"Memory usage: {final_df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
else:
    print("\nNo auction user data found for the entire specified period.")
# Out:
# --- Collecting Hourly Raw Auction Metrics (Daily Pulls) ---
# Period: 2025-03-01 to 2025-09-30
# Processing date: 2025-03-01...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-02...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-03...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-04...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-05...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-06...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-07...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-08...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-09...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-10...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-11...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-12...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-13...
#    -> Info: No auction data found for this day.
# Processing date: 2025-03-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-03-31...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-11...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-12...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-13...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-04-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-11...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-12...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-13...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-05-31...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-11...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-12...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-13...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-06-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-11...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-12...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-13...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-07-31...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-11...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-12...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-13...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-14...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-15...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-16...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-17...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-18...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-19...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-20...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-21...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-22...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-23...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-24...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-25...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-26...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-27...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-28...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-29...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-30...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-08-31...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-01...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-02...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-03...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-04...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-05...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-06...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-07...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-08...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-09...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-10...
#    -> Success: Found 24 hourly records for the day.
# Processing date: 2025-09-11...
#    -> Success: Found 22 hourly records for the day.
# Processing date: 2025-09-12...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-13...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-14...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-15...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-16...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-17...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-18...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-19...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-20...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-21...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-22...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-23...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-24...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-25...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-26...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-27...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-28...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-29...
#    -> Info: No auction data found for this day.
# Processing date: 2025-09-30...
#    -> Info: No auction data found for this day.
#
# ✅ Data successfully saved to hourly_auctions_2025-03-01_to_2025-09-30.parquet
#
# --- Aggregated Hourly Auction Metrics (Showing first 25 rows) ---
# +---------------------+------------------------+------------------------+
# | ACTIVITY_HOUR       |   HOURLY_AUCTION_COUNT |   HOURLY_AUCTION_USERS |
# +=====================+========================+========================+
# | 2025-03-14 00:00:00 |                 400303 |                  86879 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 01:00:00 |                 434713 |                  91989 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 02:00:00 |                 417098 |                  87752 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 03:00:00 |                 349522 |                  72458 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 04:00:00 |                 273594 |                  54661 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 05:00:00 |                 196081 |                  38570 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 06:00:00 |                 139139 |                  26272 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 07:00:00 |                  97685 |                  18775 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 08:00:00 |                  76510 |                  14816 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 09:00:00 |                  78407 |                  15617 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 10:00:00 |                 104068 |                  22355 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 11:00:00 |                 141404 |                  32986 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 12:00:00 |                 189328 |                  45226 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 13:00:00 |                 241607 |                  56607 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 14:00:00 |                 282814 |                  64596 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 15:00:00 |                 306987 |                  69556 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 16:00:00 |                 310704 |                  72018 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 17:00:00 |                 314644 |                  71034 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 18:00:00 |                 323262 |                  72118 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 19:00:00 |                 353487 |                  76306 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 20:00:00 |                 356438 |                  77181 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 21:00:00 |                 367599 |                  79926 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 22:00:00 |                 355223 |                  76295 |
# +---------------------+------------------------+------------------------+
# | 2025-03-14 23:00:00 |                 373887 |                  79118 |
# +---------------------+------------------------+------------------------+
# | 2025-03-15 00:00:00 |                 404976 |                  83888 |
# +---------------------+------------------------+------------------------+
